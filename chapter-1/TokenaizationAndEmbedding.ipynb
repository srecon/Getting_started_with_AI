# %%
# !pip install spacy
# !pip install numpy
# !pip install transformers
# !pip install openai
# !pip install langchain-openai

# %%
import spacy
nlp = spacy.blank("en")
tokens = nlp ("We must always change, renew, rejuvenate ourselves; otherwise, we harden.")
len (tokens)

# %%
for token in tokens:
  print (token)

# %%
import numpy as np

vector = np.array([1, 2, 3, 4, 5])

print("Vector of 5 elements:", vector)

# %%
from transformers import AutoTokenizer

from huggingface_hub import interpreter_login

interpreter_login()

# %%
model_name='microsoft/phi-2'

tokenizer = AutoTokenizer.from_pretrained(model_name,token="HF_TOKEN")

# %%
txt = "We must always change, renew, rejuvenate ourselves; otherwise, we harden."

token = tokenizer.encode(txt)
print(token)

decoded_text = tokenizer.decode(token)

print(decoded_text)

# %%
from langchain_openai import OpenAIEmbeddings

embeddings_model = OpenAIEmbeddings(api_key="YOUR_OPEN_AI_API_KEY")

# %%
txt ="Lion"
embedded_query = embeddings_model.embed_query(txt)

print (len(embedded_query))

embedded_query[:10]

# %%
txt ="Tiger"
embedded_query = embeddings_model.embed_query(txt)

print (len(embedded_query))

embedded_query[:10]

# %%
txt ="Iphone"
embedded_query = embeddings_model.embed_query(txt)

print (len(embedded_query))

embedded_query[:10]

# %%
txt ="We must always change, renew, rejuvenate ourselves; otherwise, we harden."
embedded_query = embeddings_model.embed_query(txt)

print (len(embedded_query))

embedded_query[:10]
